# %% [markdown]
# <img src="https://www.th-koeln.de/img/logo.svg" style="float:right;" width="200">

# %% [markdown]
# # 6th exercise: <font color="#C70039">Work with Autoencoders for anomaly detection</font>
# * Course: AML
# * Lecturer: <a href="https://www.gernotheisenberg.de/">Gernot Heisenberg</a>
# * Author of notebook: Finn Heydemann
# * Date:   30.10.2023
#
# <img src="https://blog.keras.io/img/ae/autoencoder_schema.jpg" style="float: center;" width="700">
#
# ---------------------------------
# **GENERAL NOTE 1**:
# Please make sure you are reading the entire notebook, since it contains a lot of information on your tasks (e.g. regarding the set of certain paramaters or a specific computational trick), and the written mark downs as well as comments contain a lot of information on how things work together as a whole.
#
# **GENERAL NOTE 2**:
# * Please, when commenting source code, just use English language only.
# * When describing an observation please use English language, too.
# * This applies to all exercises throughout this course.
#
# ---------------------------------
#
# ### <font color="ce33ff">DESCRIPTION</font>:
# Autoencoder is an unsupervised artificial neural network (ANN) that learns how to efficiently compress and encode data and then learns how to reconstruct the data back from the reduced encoded representation to a representation that is as close to the original input as possible.
#
# An Autoencoder reduces data dimensions by learning how to ignore the noise in the data and thus outliers.
# In the section above, you can seen an example of the input/output image from the MNIST dataset to an Autoencoder.
#
# #### Autoencoder Components:
# An Autoencoder consists of four main parts:
#
# 1. Encoder: In which the model learns how to reduce the input dimensions and compress the input data into an encoded representation.
#
# 2. Bottleneck: which is the layer that contains the compressed representation of the input data. This is the lowest possible dimensions of the input data. The bottlneck is also called latent vector. The concept of the latent space and latent vectors becomes important later on as we move forward to understand Generative Models.
#
# 3. Decoder: In which the model learns how to reconstruct the data from the encoded representation to be as close to the original input as possible.
#
# 4. Reconstruction Loss: This is the method that measures how well the decoder is performing and how close the output is to the original input.
#
# As always in ANNs, the training itself involves back propagation in order to minimize the network’s reconstruction loss.
#
# Due to this features of an Autoencoder the use cases are manyfold. One of the obviously is anomaly detection.
#
# #### Autoencoder Architecture:
#
# The network architecture for Autoencoders can vary between simple Feed Forward networks, Recurrent Neural Networks (LSTM) or Convolutional Neural Networks (CNN) depending on the use case.
#
# ---------------------------------
#
# ### <font color="FFC300">TASKS</font>:
# The tasks that you need to work on within this notebook are always indicated below as bullet points.
# If a task is more challenging and consists of several steps, this is indicated as well.
# Make sure you have worked down the task list and commented your doings.
# This should be done by using markdown.<br>
# <font color=red>Make sure you don't forget to specify your name and your matriculation number in the notebook.</font>
#
# **YOUR TASKS in this exercise are as follows**:
# 1. import the notebook to Google Colab or use your local machine.
# 2. make sure you specified you name and your matriculation number in the header below my name and date.
#     * set the date too and remove mine.
# 3. read the entire notebook carefully
#     * add comments whereever you feel it necessary for better understanding
#     * run the notebook for the first time.
#     * the example below shows how to use an autoencoder for anomaly detection
#
# 4. <font color=green>Develop an Autoencoder for Domain Adaptation (Me -> Walter White ). You can of course also take own data, e.g. a photo of yours and someone else.</font>
# 5. Set at least the following hyperparameters for training (epochs=100000, shuffle=True).
# 6. Implement a CNN for working out important features for the adaptation. If you feel lost in the exercise, please visit the sample solution.
# 7. There is also an implementation of data augmentation that helps you building up your data set from one single "original" image.
# ---------------------------------

# %% [markdown]
# ### Auto-Encoding
# If you have correlated input data, the auto-encoder method will work very well because the encoding operation relies on the correlated features to compress the data.
# Let’s consider that an auto-encoder is trained on the MNIST dataset.
# As you know already, using a simple FeedForward neural network, this can be done by building a simple 6 layers network as below:

# %%
import matplotlib.pyplot as plt
import numpy as np
import keras
from   keras.datasets import mnist
from   keras.models import Sequential, Model
from   keras.layers import Dense, Input
from   keras import optimizers
from   keras.optimizers import Adam

# load the inbuild mnist data set (8bit grayscale digits)
# https://en.wikipedia.org/wiki/MNIST_database
(x_train, y_train), (x_test, y_test) = mnist.load_data()
# normalize the training and the validation data set
train_x = x_train.reshape(60000, 784) / 255
val_x = x_test.reshape(10000, 784) / 255

# build the auto-encoding layers
autoencoder = Sequential()
autoencoder.add(Dense(512,  activation='elu', input_shape=(784,)))
autoencoder.add(Dense(128,  activation='elu'))
autoencoder.add(Dense(10,   activation='linear', name="bottleneck"))
autoencoder.add(Dense(128,  activation='elu'))
autoencoder.add(Dense(512,  activation='elu'))
autoencoder.add(Dense(784,  activation='sigmoid'))
autoencoder.compile(loss='mean_squared_error', optimizer = Adam())

'''
NOTE:
-----
The Exponential Linear Unit (ELU) is an activation function for neural networks. 
In contrast to ReLUs (which you know), ELUs have negative values which allows them to push mean unit 
activations closer to zero like batch normalization but with lower computational complexity.
'''    

# train the model and finally assign the encoding to the decoder
'''
NOTE:
-----
make sure you understand, that you are training on train_x and not on train_y but train_x again for the reconstruction
the same for the validation (val_x, val_x)
'''
trained_model = autoencoder.fit(train_x, train_x, batch_size=1024, epochs=10, verbose=1, validation_data=(val_x, val_x))
encoder = Model(autoencoder.input, autoencoder.get_layer('bottleneck').output)

encoded_data = encoder.predict(train_x)  # bottleneck representation

decoded_output = autoencoder.predict(train_x)        # reconstruction
encoding_dim = 10

# return the decoder
encoded_input = Input(shape=(encoding_dim,))
decoder = autoencoder.layers[-3](encoded_input)
decoder = autoencoder.layers[-2](decoder)
decoder = autoencoder.layers[-1](decoder)
decoder = Model(encoded_input, decoder)
# Out:
# 2023-11-05 19:45:42.834362: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-11-05 19:45:44.027681: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# Epoch 1/10
# 59/59 [==============================] - 4s 66ms/step - loss: 0.0761 - val_loss: 0.0485
# Epoch 2/10
# 59/59 [==============================] - 3s 50ms/step - loss: 0.0423 - val_loss: 0.0372
# Epoch 3/10
# 59/59 [==============================] - 4s 61ms/step - loss: 0.0350 - val_loss: 0.0315
# Epoch 4/10
# 59/59 [==============================] - 3s 54ms/step - loss: 0.0298 - val_loss: 0.0274
# Epoch 5/10
# 59/59 [==============================] - 3s 48ms/step - loss: 0.0268 - val_loss: 0.0252
# Epoch 6/10
# 59/59 [==============================] - 3s 54ms/step - loss: 0.0247 - val_loss: 0.0234
# Epoch 7/10
# 59/59 [==============================] - 4s 65ms/step - loss: 0.0232 - val_loss: 0.0221
# Epoch 8/10
# 59/59 [==============================] - 3s 53ms/step - loss: 0.0220 - val_loss: 0.0212
# Epoch 9/10
# 59/59 [==============================] - 3s 53ms/step - loss: 0.0211 - val_loss: 0.0204
# Epoch 10/10
# 59/59 [==============================] - 4s 61ms/step - loss: 0.0204 - val_loss: 0.0198
# 1875/1875 [==============================] - 7s 4ms/step
# 1875/1875 [==============================] - 11s 6ms/step

# %% [markdown]
# As you can see in the output, the last reconstruction loss/error for the validation set is approx. 0.0197, which is great.
# Now, if we pass any normal image from the MNIST dataset, the reconstruction loss will be very low (< 0.02) BUT if we tried to pass any other different image (outlier / anomaly), we will get a high reconstruction loss value because the network failed to reconstruct the image/input that is considered an anomaly.
#
# Notice in the code above, you can use only the encoder part to compress some data or images and you can also only use the decoder part to decompress the data by loading the decoder layers.

# %% [markdown]
# #### Auto-Encoders for Anomaly Detection
# Now, let’s do some anomaly detection. The code below uses two different images to predict the anomaly score (reconstruction error) using the autoencoder network we trained above.
#
# The first image is from the MNIST and the result is error=2.46241018. This means that the image is not an anomaly. The second image (yoda.png) obviously does not belong to the training dataset and the result is: error=2727.0718. This high error means that the image is an anomaly. Even the third image. The same concept applies to any type of dataset.

# %%
# If you are using a newer version of keras than '2.4.3', read this article below.
# It describes a versioning issue in the keras libs
'''https://stackoverflow.com/questions/72383347/how-to-fix-it-attributeerror-module-keras-preprocessing-image-has-no-attribu'''
from keras.preprocessing import image

# take an image from the validation data set or the training data set, respectively
input_img = val_x[50] 
input_img_flat = input_img.reshape(1,784)

target_data = autoencoder.predict(input_img_flat)

dist = np.linalg.norm(input_img_flat - target_data, axis=-1)

print(dist)
# Out:
# 1/1 [==============================] - 0s 38ms/step
# [2.98616218]

# %%
# Now take Master Yoda as the test image. The error score will be very high (error=2727.0718)
from tensorflow.keras.utils import load_img, img_to_array

img = load_img("./data/yoda.png", target_size=(28, 28), color_mode = "grayscale")
input_img = img_to_array(img)

input_img_flat = input_img.reshape(1,784)
target_data = autoencoder.predict(input_img_flat)
dist = np.linalg.norm(input_img_flat - target_data, axis=-1)
print(dist)
# Out:
# 1/1 [==============================] - 0s 20ms/step
# [2726.978]

# %%
''' 
Now take a Mnist image which is taken from the google image search and although it is super similar to the training data
it does not belong to the same data distribution the auto-encoder was trained on. 
It produces an error almost as high as yoda.png (approx error=2551.99)
This makes autoencoders being a very robust technique for anomaly detection.
'''
img = load_img("./data/similarMnistNumber.jpg", target_size=(28, 28), color_mode = "grayscale")
input_img = img_to_array(img)

input_img_flat = input_img.reshape(1,784)
target_data = autoencoder.predict(input_img_flat)
dist = np.linalg.norm(input_img_flat - target_data, axis=-1)

print(dist)
# Out:
# 1/1 [==============================] - 0s 24ms/step
# [2551.976]

# %% [markdown]
# ## Autoencoder Gernot Heisenberg -- Walter White

# %%
import cv2
import os 
import matplotlib.pyplot as plt 
import numpy as np 
# Read the data 

input_path = "data/heisenberg_heisenberg/gernot"
inputs = []
SIZE = 256

for img in next(os.walk(input_path))[2]: 
    inputs.append(cv2.resize(cv2.imread(os.path.join(input_path, img), 1), (SIZE, SIZE)))

# %%
inputs = np.stack(inputs)
plt.imshow(inputs[1])

# %%
output_path = "data/heisenberg_heisenberg/walter"
outputs = []
for img in next(os.walk(output_path))[2]: 
    outputs.append(cv2.resize(cv2.imread(os.path.join(output_path, img), 1), (SIZE, SIZE)))

# %%
outputs = np.stack(outputs)
plt.imshow(outputs[5])

# %%
inputs = inputs / 255
outputs = outputs / 255

# %%
from tensorflow.keras.layers import Conv2D, MaxPooling2D, UpSampling2D
from tensorflow.keras.models import Sequential

encoder = Sequential()
encoder.add(Conv2D(32, (3, 3), activation="relu", padding="same", input_shape=(SIZE, SIZE, 3)))
encoder.add(MaxPooling2D((2, 2), padding="same"))
encoder.add(Conv2D(8, (3, 3), activation='relu', padding='same'))
encoder.add(MaxPooling2D((2, 2), padding='same'))
encoder.add(Conv2D(8, (3, 3), activation='relu', padding='same'))
encoder.add(MaxPooling2D((2, 2), padding='same'))

decoder = Sequential()
decoder.add(Conv2D(8, (3, 3), activation='relu', padding='same'))
decoder.add(UpSampling2D((2, 2)))
decoder.add(Conv2D(8, (3, 3), activation='relu', padding='same'))
decoder.add(UpSampling2D((2, 2)))
decoder.add(Conv2D(32, (3, 3), activation='relu', padding='same'))
decoder.add(UpSampling2D((2, 2)))
decoder.add(Conv2D(3, (3, 3), activation='relu', padding='same'))

autoencoder = Sequential([encoder, decoder])

autoencoder.compile(loss="mse", optimizer="adam", metrics=["accuracy"])

# %%
encoder.summary(), decoder.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 256, 256, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 128, 128, 32)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 128, 128, 8)       2312
#
#  max_pooling2d_1 (MaxPooling  (None, 64, 64, 8)        0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 64, 64, 8)         584
#
#  max_pooling2d_2 (MaxPooling  (None, 32, 32, 8)        0
#  2D)
#
# =================================================================
# Total params: 3,792
# Trainable params: 3,792
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_3 (Conv2D)           (None, 32, 32, 8)         584
#
#  up_sampling2d (UpSampling2D  (None, 64, 64, 8)        0
#  )
#
#  conv2d_4 (Conv2D)           (None, 64, 64, 8)         584
#
#  up_sampling2d_1 (UpSampling  (None, 128, 128, 8)      0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 128, 128, 32)      2336
#
#  up_sampling2d_2 (UpSampling  (None, 256, 256, 32)     0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 256, 256, 3)       867
#
# =================================================================
# Total params: 4,371
# Trainable params: 4,371
# Non-trainable params: 0
# _________________________________________________________________
# (None, None)

# %%
autoencoder.fit(inputs, outputs, epochs=25000, shuffle=True)
# Out:
# Epoch 1/25000
# 2/2 [==============================] - 2s 560ms/step - loss: 0.1539 - accuracy: 0.7876
# Epoch 2/25000
# 2/2 [==============================] - 2s 634ms/step - loss: 0.1420 - accuracy: 0.9439
# Epoch 3/25000
# 2/2 [==============================] - 2s 613ms/step - loss: 0.1226 - accuracy: 0.9500
# Epoch 4/25000
# 2/2 [==============================] - 1s 602ms/step - loss: 0.1024 - accuracy: 0.9471
# Epoch 5/25000
# 2/2 [==============================] - 1s 591ms/step - loss: 0.1085 - accuracy: 0.9498
# Epoch 6/25000
# 2/2 [==============================] - 1s 590ms/step - loss: 0.1049 - accuracy: 0.9553
# Epoch 7/25000
# 2/2 [==============================] - 1s 575ms/step - loss: 0.0987 - accuracy: 0.9561
# Epoch 8/25000
# 2/2 [==============================] - 1s 563ms/step - loss: 0.1001 - accuracy: 0.9563
# Epoch 9/25000
# 2/2 [==============================] - 2s 606ms/step - loss: 0.1013 - accuracy: 0.9562
# Epoch 10/25000
# 2/2 [==============================] - 2s 625ms/step - loss: 0.0998 - accuracy: 0.9560
# Epoch 11/25000
# 2/2 [==============================] - 2s 617ms/step - loss: 0.0965 - accuracy: 0.9559
# Epoch 12/25000
# 2/2 [==============================] - 2s 587ms/step - loss: 0.0899 - accuracy: 0.9558
# Epoch 13/25000
# 2/2 [==============================] - 2s 586ms/step - loss: 0.0806 - accuracy: 0.9553
# Epoch 14/25000
# 2/2 [==============================] - 2s 712ms/step - loss: 0.0769 - accuracy: 0.9472
# Epoch 15/25000
# 2/2 [==============================] - 2s 605ms/step - loss: 0.0736 - accuracy: 0.9203
# Epoch 16/25000
# 2/2 [==============================] - 1s 620ms/step - loss: 0.0737 - accuracy: 0.8533
# Epoch 17/25000
# 2/2 [==============================] - 2s 634ms/step - loss: 0.0750 - accuracy: 0.7433
# Epoch 18/25000
# 2/2 [==============================] - 2s 611ms/step - loss: 0.0743 - accuracy: 0.6742
# Epoch 19/25000
# 2/2 [==============================] - 2s 641ms/step - loss: 0.0728 - accuracy: 0.7493
# Epoch 20/25000
# 2/2 [==============================] - 2s 629ms/step - loss: 0.0718 - accuracy: 0.8864
# Epoch 21/25000
# 2/2 [==============================] - 2s 631ms/step - loss: 0.0703 - accuracy: 0.9366
# Epoch 22/25000
# 2/2 [==============================] - 2s 582ms/step - loss: 0.0694 - accuracy: 0.9515
# Epoch 23/25000
# 2/2 [==============================] - 2s 590ms/step - loss: 0.0690 - accuracy: 0.9557
# Epoch 24/25000
# 2/2 [==============================] - 2s 667ms/step - loss: 0.0684 - accuracy: 0.9561
# Epoch 25/25000
# 2/2 [==============================] - 2s 540ms/step - loss: 0.0680 - accuracy: 0.9562
# Epoch 26/25000
# 2/2 [==============================] - 2s 677ms/step - loss: 0.0675 - accuracy: 0.9564
# Epoch 27/25000
# 2/2 [==============================] - 1s 492ms/step - loss: 0.0669 - accuracy: 0.9564
# Epoch 28/25000
# 2/2 [==============================] - 2s 567ms/step - loss: 0.0664 - accuracy: 0.9563
# Epoch 29/25000
# 2/2 [==============================] - 2s 603ms/step - loss: 0.0656 - accuracy: 0.9562
# Epoch 30/25000
# 2/2 [==============================] - 2s 570ms/step - loss: 0.0653 - accuracy: 0.9561
# Epoch 31/25000
# 2/2 [==============================] - 2s 546ms/step - loss: 0.0651 - accuracy: 0.9561
# Epoch 32/25000
# 2/2 [==============================] - 2s 593ms/step - loss: 0.0651 - accuracy: 0.9561
# Epoch 33/25000
# 2/2 [==============================] - 2s 636ms/step - loss: 0.0649 - accuracy: 0.9561
# Epoch 34/25000
# 2/2 [==============================] - 2s 722ms/step - loss: 0.0646 - accuracy: 0.9561
# Epoch 35/25000
# 2/2 [==============================] - 2s 645ms/step - loss: 0.0644 - accuracy: 0.9561
# Epoch 36/25000
# Epoch 458/25000
# 2/2 [==============================] - 2s 658ms/step - loss: 0.0561 - accuracy: 0.9597
# Epoch 459/25000
# 2/2 [==============================] - 2s 587ms/step - loss: 0.0559 - accuracy: 0.9597
# Epoch 460/25000
# 2/2 [==============================] - 1s 563ms/step - loss: 0.0552 - accuracy: 0.9597
# Epoch 461/25000
# 2/2 [==============================] - 2s 592ms/step - loss: 0.0550 - accuracy: 0.9597
# Epoch 462/25000
# 2/2 [==============================] - 2s 627ms/step - loss: 0.0545 - accuracy: 0.9597
# Epoch 463/25000
# 2/2 [==============================] - 2s 717ms/step - loss: 0.0552 - accuracy: 0.9597
# Epoch 464/25000
# 2/2 [==============================] - 2s 616ms/step - loss: 0.0546 - accuracy: 0.9597
# Epoch 465/25000
# 2/2 [==============================] - 2s 567ms/step - loss: 0.0543 - accuracy: 0.9597
# Epoch 466/25000
# 2/2 [==============================] - 2s 702ms/step - loss: 0.0552 - accuracy: 0.9597
# Epoch 467/25000
# 2/2 [==============================] - 2s 610ms/step - loss: 0.0554 - accuracy: 0.9597
# ...
# Epoch 8797/25000
# 2/2 [==============================] - 2s 627ms/step - loss: 0.0325 - accuracy: 0.9596
# Epoch 8798/25000
# 2/2 [==============================] - 2s 623ms/step - loss: 0.0320 - accuracy: 0.9596
# Epoch 8799/25000
# 2/2 [==============================] - 2s 627ms/step - loss: 0.0325 - accuracy: 0.9596
# Epoch 8800/25000
# 2/2 [==============================] - 1s 593ms/step - loss: 0.0319 - accuracy: 0.9596
# Epoch 8801/25000
# 2/2 [==============================] - 2s 589ms/step - loss: 0.0318 - accuracy: 0.9596
# Epoch 8802/25000
# 2/2 [==============================] - 2s 656ms/step - loss: 0.0320 - accuracy: 0.9596
# Epoch 8803/25000
# 2/2 [==============================] - 2s 592ms/step - loss: 0.0318 - accuracy: 0.9596
# Epoch 8804/25000
# 2/2 [==============================] - 2s 616ms/step - loss: 0.0319 - accuracy: 0.9596
# Epoch 8805/25000
# 2/2 [==============================] - 2s 709ms/step - loss: 0.0321 - accuracy: 0.9596
# Epoch 8806/25000
# 2/2 [==============================] - 2s 613ms/step - loss: 0.0318 - accuracy: 0.9596
# Epoch 8807/25000
# 2/2 [==============================] - 1s 570ms/step - loss: 0.0318 - accuracy: 0.9596
# Epoch 8808/25000
# 2/2 [==============================] - 1s 554ms/step - loss: 0.0317 - accuracy: 0.9596
# Epoch 8809/25000
# 2/2 [==============================] - 1s 522ms/step - loss: 0.0319 - accuracy: 0.9596
# Epoch 8810/25000
# 2/2 [==============================] - 1s 558ms/step - loss: 0.0318 - accuracy: 0.9596
# Epoch 8811/25000
# 2/2 [==============================] - 1s 628ms/step - loss: 0.0322 - accuracy: 0.9596
# Epoch 8812/25000
# 2/2 [==============================] - 2s 623ms/step - loss: 0.0315 - accuracy: 0.9596
# Epoch 8813/25000
# 2/2 [==============================] - 2s 741ms/step - loss: 0.0324 - accuracy: 0.9596
# Epoch 8814/25000
# 2/2 [==============================] - 2s 637ms/step - loss: 0.0350 - accuracy: 0.9596
# Epoch 8815/25000
# 2/2 [==============================] - 1s 645ms/step - loss: 0.0354 - accuracy: 0.9595
# Epoch 8816/25000
# 2/2 [==============================] - 2s 612ms/step - loss: 0.0340 - accuracy: 0.9595
# Epoch 8817/25000
# 2/2 [==============================] - 2s 656ms/step - loss: 0.0337 - accuracy: 0.9596
# Epoch 8818/25000
# 2/2 [==============================] - 2s 567ms/step - loss: 0.0328 - accuracy: 0.9596
# Epoch 8819/25000
# 2/2 [==============================] - 2s 695ms/step - loss: 0.0330 - accuracy: 0.9596
# Epoch 8820/25000
# 2/2 [==============================] - 1s 551ms/step - loss: 0.0330 - accuracy: 0.9595
# Epoch 8821/25000
# 2/2 [==============================] - 2s 579ms/step - loss: 0.0327 - accuracy: 0.9596
# Epoch 8822/25000
# 2/2 [==============================] - 2s 679ms/step - loss: 0.0323 - accuracy: 0.9596
# Epoch 8823/25000
# 2/2 [==============================] - 2s 590ms/step - loss: 0.0324 - accuracy: 0.9595
# Epoch 8824/25000
# 2/2 [==============================] - 2s 670ms/step - loss: 0.0321 - accuracy: 0.9595
# Epoch 8825/25000
# 2/2 [==============================] - 2s 577ms/step - loss: 0.0318 - accuracy: 0.9596
# Epoch 8826/25000
# 2/2 [==============================] - 2s 658ms/step - loss: 0.0318 - accuracy: 0.9596
# Epoch 8827/25000
# 2/2 [==============================] - 1s 582ms/step - loss: 0.0318 - accuracy: 0.9596
# Epoch 8828/25000
# 2/2 [==============================] - 2s 669ms/step - loss: 0.0317 - accuracy: 0.9596
# Epoch 8829/25000
# 2/2 [==============================] - 2s 614ms/step - loss: 0.0316 - accuracy: 0.9596
# Epoch 8830/25000
# 2/2 [==============================] - 2s 581ms/step - loss: 0.0319 - accuracy: 0.9596
# Epoch 8831/25000
# 2/2 [==============================] - 2s 643ms/step - loss: 0.0317 - accuracy: 0.9596
# Epoch 8832/25000
# 2/2 [==============================] - 2s 625ms/step - loss: 0.0317 - accuracy: 0.9596
# Epoch 8833/25000
# 2/2 [==============================] - 2s 612ms/step - loss: 0.0318 - accuracy: 0.9596
# Epoch 8834/25000
# 2/2 [==============================] - 1s 642ms/step - loss: 0.0316 - accuracy: 0.9596
# Epoch 8835/25000
# 2/2 [==============================] - 2s 594ms/step - loss: 0.0315 - accuracy: 0.9596
# Epoch 8836/25000
# 2/2 [==============================] - 2s 625ms/step - loss: 0.0315 - accuracy: 0.9596
# Epoch 8837/25000
# 2/2 [==============================] - 2s 650ms/step - loss: 0.0315 - accuracy: 0.9596
# Epoch 8838/25000
# 2/2 [==============================] - 2s 668ms/step - loss: 0.0315 - accuracy: 0.9596
# Epoch 8839/25000
# 2/2 [==============================] - 2s 680ms/step - loss: 0.0322 - accuracy: 0.9596
# Epoch 8840/25000
# 2/2 [==============================] - 2s 640ms/step - loss: 0.0318 - accuracy: 0.9596
# Epoch 8841/25000
# 2/2 [==============================] - 2s 527ms/step - loss: 0.0320 - accuracy: 0.9596
# Epoch 8842/25000
# 2/2 [==============================] - 2s 649ms/step - loss: 0.0315 - accuracy: 0.9596
# Epoch 8843/25000
# 2/2 [==============================] - 2s 563ms/step - loss: 0.0315 - accuracy: 0.9596
# Epoch 8844/25000
# 2/2 [==============================] - 1s 561ms/step - loss: 0.0317 - accuracy: 0.9596
# Epoch 8845/25000
# 2/2 [==============================] - 2s 652ms/step - loss: 0.0318 - accuracy: 0.9596
# Epoch 8846/25000
# 2/2 [==============================] - 2s 608ms/step - loss: 0.0331 - accuracy: 0.9596
# Epoch 8847/25000
# 2/2 [==============================] - 2s 679ms/step - loss: 0.0330 - accuracy: 0.9596
# Epoch 8848/25000
# 2/2 [==============================] - 2s 659ms/step - loss: 0.0344 - accuracy: 0.9596
# Epoch 8849/25000
# 2/2 [==============================] - 2s 637ms/step - loss: 0.0354 - accuracy: 0.9595
# Epoch 8850/25000
# 2/2 [==============================] - 2s 612ms/step - loss: 0.0335 - accuracy: 0.9596
# Epoch 8851/25000
# 2/2 [==============================] - 2s 647ms/step - loss: 0.0328 - accuracy: 0.9596
# Epoch 8852/25000
# 2/2 [==============================] - 2s 592ms/step - loss: 0.0323 - accuracy: 0.9596
# Epoch 8853/25000
# 2/2 [==============================] - 2s 762ms/step - loss: 0.0322 - accuracy: 0.9596
# Epoch 8854/25000
# 2/2 [==============================] - 2s 655ms/step - loss: 0.0319 - accuracy: 0.9596
# Epoch 8855/25000
# 2/2 [==============================] - 2s 585ms/step - loss: 0.0323 - accuracy: 0.9596
# Epoch 8856/25000
# 2/2 [==============================] - 2s 620ms/step - loss: 0.0320 - accuracy: 0.9595
# Epoch 8857/25000
# 2/2 [==============================] - 2s 603ms/step - loss: 0.0321 - accuracy: 0.9596
# Epoch 8858/25000
# 2/2 [==============================] - 2s 590ms/step - loss: 0.0335 - accuracy: 0.9596
# Epoch 8859/25000
# 2/2 [==============================] - 1s 608ms/step - loss: 0.0348 - accuracy: 0.9596
# Epoch 8860/25000
# 2/2 [==============================] - 1s 586ms/step - loss: 0.0343 - accuracy: 0.9596
# Epoch 8861/25000
# 2/2 [==============================] - 2s 553ms/step - loss: 0.0329 - accuracy: 0.9596
# Epoch 8862/25000
# 2/2 [==============================] - 1s 565ms/step - loss: 0.0329 - accuracy: 0.9596
# Epoch 8863/25000
# 2/2 [==============================] - 2s 607ms/step - loss: 0.0331 - accuracy: 0.9596
# Epoch 8864/25000
# 2/2 [==============================] - 2s 616ms/step - loss: 0.0331 - accuracy: 0.9596
# Epoch 8865/25000
# 2/2 [==============================] - 2s 581ms/step - loss: 0.0333 - accuracy: 0.9596
# Epoch 8866/25000
# 2/2 [==============================] - 2s 641ms/step - loss: 0.0335 - accuracy: 0.9596
# Epoch 8867/25000
# 2/2 [==============================] - 2s 559ms/step - loss: 0.0332 - accuracy: 0.9595
# Epoch 8868/25000
# 2/2 [==============================] - 2s 630ms/step - loss: 0.0328 - accuracy: 0.9596
# Epoch 8869/25000
# 2/2 [==============================] - 2s 684ms/step - loss: 0.0327 - accuracy: 0.9596
# Epoch 8870/25000
# 2/2 [==============================] - 2s 658ms/step - loss: 0.0325 - accuracy: 0.9596
# Epoch 8871/25000
# 2/2 [==============================] - 2s 587ms/step - loss: 0.0324 - accuracy: 0.9596
# Epoch 8872/25000
# 2/2 [==============================] - 2s 609ms/step - loss: 0.0323 - accuracy: 0.9596
# Epoch 8873/25000
# 2/2 [==============================] - 2s 623ms/step - loss: 0.0327 - accuracy: 0.9596
# Epoch 8874/25000
# 2/2 [==============================] - 1s 496ms/step - loss: 0.0330 - accuracy: 0.9596
# Epoch 8875/25000
# 2/2 [==============================] - 1s 539ms/step - loss: 0.0330 - accuracy: 0.9596
# Epoch 8876/25000
# 2/2 [==============================] - 2s 619ms/step - loss: 0.0321 - accuracy: 0.9596
# Epoch 8877/25000
# 2/2 [==============================] - 2s 621ms/step - loss: 0.0320 - accuracy: 0.9596
# Epoch 8878/25000
# 2/2 [==============================] - 2s 602ms/step - loss: 0.0319 - accuracy: 0.9596
# Epoch 8879/25000
# 2/2 [==============================] - 2s 597ms/step - loss: 0.0318 - accuracy: 0.9596
# Epoch 8880/25000
# 2/2 [==============================] - 2s 618ms/step - loss: 0.0317 - accuracy: 0.9596
# Epoch 8881/25000
# 2/2 [==============================] - 1s 610ms/step - loss: 0.0318 - accuracy: 0.9596
# Epoch 8882/25000
# 2/2 [==============================] - 2s 642ms/step - loss: 0.0316 - accuracy: 0.9596
# Epoch 8883/25000
# 2/2 [==============================] - 2s 625ms/step - loss: 0.0316 - accuracy: 0.9596
# Epoch 8884/25000
# 2/2 [==============================] - 2s 633ms/step - loss: 0.0317 - accuracy: 0.9596
# Epoch 8885/25000
# 2/2 [==============================] - 2s 572ms/step - loss: 0.0318 - accuracy: 0.9596
# Epoch 8886/25000
# 2/2 [==============================] - 2s 647ms/step - loss: 0.0318 - accuracy: 0.9596
# Epoch 8887/25000
# 2/2 [==============================] - 2s 665ms/step - loss: 0.0320 - accuracy: 0.9596
# Epoch 8888/25000
# 2/2 [==============================] - 2s 655ms/step - loss: 0.0321 - accuracy: 0.9596
# Epoch 8889/25000
# 2/2 [==============================] - 2s 619ms/step - loss: 0.0317 - accuracy: 0.9596
# Epoch 8890/25000
# 2/2 [==============================] - 2s 617ms/step - loss: 0.0317 - accuracy: 0.9596
# Epoch 8891/25000
# 2/2 [==============================] - 2s 686ms/step - loss: 0.0316 - accuracy: 0.9596
# Epoch 8892/25000
# 2/2 [==============================] - 2s 589ms/step - loss: 0.0317 - accuracy: 0.9596
# Epoch 8893/25000
# 2/2 [==============================] - 1s 495ms/step - loss: 0.0316 - accuracy: 0.9596
# Epoch 8894/25000
# 2/2 [==============================] - 2s 618ms/step - loss: 0.0317 - accuracy: 0.9596
# Epoch 8895/25000
# 2/2 [==============================] - 2s 603ms/step - loss: 0.0332 - accuracy: 0.9596
# Epoch 8896/25000
# 2/2 [==============================] - 2s 584ms/step - loss: 0.0327 - accuracy: 0.9596
# Epoch 8897/25000
# 2/2 [==============================] - 2s 649ms/step - loss: 0.0325 - accuracy: 0.9596
# Epoch 8898/25000
# 2/2 [==============================] - 2s 571ms/step - loss: 0.0327 - accuracy: 0.9596
# Epoch 8899/25000
# 2/2 [==============================] - 1s 591ms/step - loss: 0.0330 - accuracy: 0.9596
# Epoch 8900/25000
# 2/2 [==============================] - 1s 563ms/step - loss: 0.0321 - accuracy: 0.9596
# Epoch 8901/25000
# 2/2 [==============================] - 2s 599ms/step - loss: 0.0319 - accuracy: 0.9596
# Epoch 8902/25000
# 2/2 [==============================] - 2s 552ms/step - loss: 0.0318 - accuracy: 0.9596
# Epoch 8903/25000
# 2/2 [==============================] - 2s 584ms/step - loss: 0.0318 - accuracy: 0.9595
# Epoch 8904/25000
# 2/2 [==============================] - 2s 652ms/step - loss: 0.0319 - accuracy: 0.9596
# Epoch 8905/25000
# 2/2 [==============================] - 2s 668ms/step - loss: 0.0317 - accuracy: 0.9596
# Epoch 8906/25000
# 2/2 [==============================] - 2s 669ms/step - loss: 0.0319 - accuracy: 0.9596
# Epoch 8907/25000
# 2/2 [==============================] - 2s 652ms/step - loss: 0.0316 - accuracy: 0.9596
# Epoch 8908/25000
# 2/2 [==============================] - 2s 642ms/step - loss: 0.0317 - accuracy: 0.9596
# Epoch 8909/25000
# 2/2 [==============================] - 2s 654ms/step - loss: 0.0315 - accuracy: 0.9596
# Epoch 8910/25000
# 2/2 [==============================] - 1s 601ms/step - loss: 0.0315 - accuracy: 0.9596
# Epoch 8911/25000
# 2/2 [==============================] - 1s 545ms/step - loss: 0.0316 - accuracy: 0.9596
# Epoch 8912/25000
# 2/2 [==============================] - 2s 621ms/step - loss: 0.0318 - accuracy: 0.9596
# Epoch 8913/25000
# 2/2 [==============================] - 2s 579ms/step - loss: 0.0318 - accuracy: 0.9596
# Epoch 8914/25000
# 2/2 [==============================] - 2s 680ms/step - loss: 0.0320 - accuracy: 0.9596
# Epoch 8915/25000
# 2/2 [==============================] - 2s 549ms/step - loss: 0.0315 - accuracy: 0.9596
# Epoch 8916/25000
# 2/2 [==============================] - 2s 622ms/step - loss: 0.0317 - accuracy: 0.9596
# Epoch 8917/25000
# 2/2 [==============================] - 2s 600ms/step - loss: 0.0316 - accuracy: 0.9596
# Epoch 8918/25000
# 2/2 [==============================] - 2s 554ms/step - loss: 0.0316 - accuracy: 0.9596
# Epoch 8919/25000
# 2/2 [==============================] - 1s 560ms/step - loss: 0.0325 - accuracy: 0.9596
# Epoch 8920/25000
# 2/2 [==============================] - 2s 570ms/step - loss: 0.0328 - accuracy: 0.9596
# Epoch 8921/25000
# 2/2 [==============================] - 2s 577ms/step - loss: 0.0330 - accuracy: 0.9596
# Epoch 8922/25000
# 2/2 [==============================] - 2s 650ms/step - loss: 0.0327 - accuracy: 0.9596
# Epoch 8923/25000
# 2/2 [==============================] - 2s 534ms/step - loss: 0.0326 - accuracy: 0.9596
# Epoch 8924/25000
# 2/2 [==============================] - 2s 670ms/step - loss: 0.0327 - accuracy: 0.9595
# Epoch 8925/25000
# 2/2 [==============================] - 2s 592ms/step - loss: 0.0327 - accuracy: 0.9595
# Epoch 8926/25000
# 2/2 [==============================] - 2s 594ms/step - loss: 0.0320 - accuracy: 0.9595
# Epoch 8927/25000
# 2/2 [==============================] - 2s 657ms/step - loss: 0.0322 - accuracy: 0.9595
# Epoch 8928/25000
# 2/2 [==============================] - 2s 649ms/step - loss: 0.0322 - accuracy: 0.9595
# Epoch 8929/25000
# 2/2 [==============================] - 1s 569ms/step - loss: 0.0319 - accuracy: 0.9596
# Epoch 8930/25000
# 2/2 [==============================] - 2s 611ms/step - loss: 0.0330 - accuracy: 0.9596
# Epoch 8931/25000
# 2/2 [==============================] - 2s 606ms/step - loss: 0.0343 - accuracy: 0.9596
# Epoch 8932/25000
# 2/2 [==============================] - 2s 690ms/step - loss: 0.0339 - accuracy: 0.9596
# Epoch 8933/25000
# 2/2 [==============================] - 2s 588ms/step - loss: 0.0328 - accuracy: 0.9596
# Epoch 8934/25000
# 2/2 [==============================] - 2s 637ms/step - loss: 0.0323 - accuracy: 0.9596
# Epoch 8935/25000
# 2/2 [==============================] - 2s 714ms/step - loss: 0.0321 - accuracy: 0.9596
# Epoch 8936/25000
# 2/2 [==============================] - 2s 580ms/step - loss: 0.0320 - accuracy: 0.9596
# Epoch 8937/25000
# 2/2 [==============================] - 1s 541ms/step - loss: 0.0319 - accuracy: 0.9596
# Epoch 8938/25000
# 2/2 [==============================] - 2s 723ms/step - loss: 0.0318 - accuracy: 0.9596
# Epoch 8939/25000
# 2/2 [==============================] - 2s 567ms/step - loss: 0.0316 - accuracy: 0.9596
# Epoch 8940/25000
# 2/2 [==============================] - 2s 696ms/step - loss: 0.0318 - accuracy: 0.9596
# Epoch 8941/25000
# 2/2 [==============================] - 2s 617ms/step - loss: 0.0321 - accuracy: 0.9596
# Epoch 8942/25000
# 2/2 [==============================] - 2s 595ms/step - loss: 0.0319 - accuracy: 0.9596
# Epoch 8943/25000
# 2/2 [==============================] - 2s 576ms/step - loss: 0.0316 - accuracy: 0.9596
# Epoch 8944/25000
# 2/2 [==============================] - 2s 652ms/step - loss: 0.0318 - accuracy: 0.9596
# Epoch 8945/25000
# 2/2 [==============================] - 2s 639ms/step - loss: 0.0319 - accuracy: 0.9596
# Epoch 8946/25000
# 2/2 [==============================] - 2s 695ms/step - loss: 0.0319 - accuracy: 0.9596
# Epoch 8947/25000
# 2/2 [==============================] - 1s 597ms/step - loss: 0.0321 - accuracy: 0.9596
# Epoch 8948/25000
# 2/2 [==============================] - 1s 536ms/step - loss: 0.0327 - accuracy: 0.9596
# Epoch 8949/25000
# 2/2 [==============================] - 2s 585ms/step - loss: 0.0322 - accuracy: 0.9596
# Epoch 8950/25000

# %%
test_img = cv2.resize(cv2.imread("data/heisenberg_heisenberg/gernot-heisenberg-original.jpg"), (SIZE, SIZE))
test_img = test_img / 255

# %%
walter = autoencoder.predict(test_img[np.newaxis, :])
plt.imshow(walter[0])
